# %% [markdown]
# Read All Libraries

# %%
import pandas as pd 
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline

# %% [markdown]
# Read Data

# %%
data=pd.read_csv(r'C:\Users\Akhmad\Downloads\Animal-Disease-Prediction-main\Prediksi Penyakit Pada Hewan\Animal_Disease_dataset.csv')

# %%
data
# Out:
#     AnimalName                        symptoms1             symptoms2  \
# 0          Dog                            Fever              Diarrhea
# 1          Dog                            Fever              Diarrhea
# 2          Dog                            Fever              Diarrhea
# 3          Dog                            Fever  Difficulty breathing
# 4          Dog                            Fever              Diarrhea
# ..         ...                              ...                   ...
# 866  Buffaloes                            Fever  Difficulty breathing
# 867  Buffaloes                            Fever     Loss of  appetite
# 868  Buffaloes      Lesions in the nasal cavity       Lesions on nose
# 869  Buffaloes                        Hair loss              Dandruff
# 870  Buffaloes  Greenish-yellow nasal discharge  Lack of pigmentation
#
#                symptoms3             symptoms4           symptoms5 Dangerous  \
# 0               Vomiting           Weight loss         Dehydration       Yes
# 1               Coughing             Tiredness               Pains       Yes
# 2               Coughing              Vomiting            Anorexia       Yes
# 3               Coughing              Lethargy            Sneezing       Yes
# 4               Coughing              Lethargy            Blue Eye       Yes
# ..                   ...                   ...                 ...       ...
# 866        Poor Appetite   Eye and Skin change  Unable to exercise       Yes
# 867  Lession on the skin              Lethargy          Joint Pain       Yes
# 868             Vomiting       Noisy Breathing     Lesions on nose       Yes
# 869             Vomiting  Crusting of the skin      Ulcerated skin       Yes
# 870             Vomiting              Lethargy        Pain on face       Yes
#
#                          Disease
# 0              Canine Parvovirus
# 1             Canine Coronavirus
# 2              Canine Distemper
# 3               Canine Influenza
# 4    Infectious canine hepatitis
# ..                           ...
# 866               Histoplasmosis
# 867           Coccidioidomycosis
# 868               Cryptococcosis
# 869                    Ring worm
# 870                Aspergillosis
#
# [871 rows x 8 columns]

# %% [markdown]
# Check Shape of data

# %%
data.shape
# Out:
# (871, 8)

# %%
len(data)
# Out:
# 871

# %%
jenis_penyakit = data['Disease'].unique()
print("Jumlah jenis penyakit:", len(jenis_penyakit))
print("Jenis penyakit yang ada:", jenis_penyakit)
# Out:
# Jumlah jenis penyakit: 335
# Jenis penyakit yang ada: ['Canine Parvovirus' 'Canine Coronavirus' 'Canine Distemper '
#  'Canine Influenza' 'Infectious canine hepatitis' 'Pseudorabies'
#  'Mast Cell Tumor' 'Melonoma(Mouth)' 'Lymphoma' 'Osteosarcoma'
#  'Hemangiosarcoma' 'Brucellosis' 'Leptospirosis' 'Lyme' 'Ehrlichiosis'
#  'Rocky mountain spotted fever' 'Clostridium' 'Kennel cough'
#  'Blastomycosis' 'Histoplasmosis' 'Coccidioidomycosis' 'Cryptococcosis'
#  'Ring worm' 'Aspergillosis' 'Pythiosis' 'Mucormycosis' 'Glardiasis'
#  'Coccidiosis' 'Protothecosis' 'Trichinosis' 'Echinococcosis' 'HeartWorm'
#  'Panosteitis' 'Luxating Patella ' 'Feline herpesvirus'
#  'Feline calicivirus' 'Rabies' 'Bladder Cancer' 'Bone caner'
#  'Intestinal cancer' 'Liver cancer' 'mammary cancer' 'mast cell tumor'
#  'Nose cancer' 'Skin cancer' 'Stomach cancer' 'Ear mites' 'Heartworm'
#  'Hookworm' 'Familial renal disease' 'Diabiatics' 'Epilesy' 'Asthma'
#  'hepatic lipidosis' 'Ticks' 'Fleas' 'cerebellar hypoplasia'
#  'Corneal Ulcer' 'Zoonosis' 'patesurella multicida' 'salmonella poisoning'
#  'Scabies' 'Giardiasis' 'Bladder stone' 'Cat bite' 'Toxoplasmosis'
#  'bordetella bronchiseptica' 'Bordetela holmessi' 'Buboni plaque'
#  'Hair ball' 'myxomatosis' 'pasteurella' ' Esherichia coli' 'Hemorhagic'
#  'Rabbit pox' 'Papilloma' 'Tularemia' 'Tyzzer' 'verminosis' 'fowl cholera'
#  'coccidiosis' 'fowl pox' 'Salmonellosis' 'foot disease' 'Mouth Disease'
#  'brucellosis' 'mastitis ' 'Anthrax' 'Black Quarter' 'Calf Disptherich'
#  'Coccoidiosis' 'Contagious Bovin' 'Cow pox' 'Diarrhea' 'Dysentery'
#  'Haemorrhagic' 'Johnes Disease' 'Mastities' 'Parasitic Disease'
#  'Milk fever' 'Pnemonia' 'Rinder Pest' 'Tuberculosis' 'Tympany'
#  'Cryptosporidiosis' 'Encephalitis' 'MRSA' 'Ringworm' 'Salmonella'
#  'Tickborne' 'Superfacial wounds' 'Vitamin A deficiency' 'Shell injection'
#  'Wet Tail' 'Lymphocyctes' 'Pseudotuberculosis' 'Tapeworm' 'Filariasis '
#  'Sarcoptic Mange ' 'Pentastomiasis' 'Enchinococcosis' 'Taeniasis'
#  'Hepatozoonosis ' 'Antrax ' 'Rickets ' 'Babesiosis' 'Bovine tuberculosis'
#  'Feline Parvovirus' 'Feline infection peritonitics'
#  'Faline leukaemia virus' 'White muscle' 'Mites' 'Toxoplasma gondii'
#  'intestinal worms' 'Flukes' 'Lungworm' 'campylobacteriosis' 'Listeriosis'
#  'ORF' 'Q fever' 'leptospirosis' 'Mycoplasma' 'Goat pox'
#  'Haemorrhagic Septicemia' 'Pneumonia' 'Foot Rot'
#  'Peste Des Petits Ruminants (PPR)' 'Foot and mouth disease'
#  'Flue infection' 'Round Worm' 'Tick' 'Pink eye'
#  'Deficiency of vitamin B1' 'Haemonchosis' 'Qfever' 'leptospisos'
#  'campylobacterosis' 'giardiasis' 'Chronic Wasting' 'avian influenza'
#  'New castle' 'Botulism' 'infectious coryza' "Marek's" 'Thrush' 'Air sac'
#  'Pullorium' 'Simian immunodeficiency' 'Rhinitis' 'Nasal cavity'
#  'Trachiobronchial' 'Airsacculitis' 'Ashtma' 'Syntical virus' 'Measles'
#  'Influenza A and B' 'Metapneumovirus' 'Adenovirus' 'SARS corona virus'
#  'Pneumococcal infection' 'Upper respiratory infection'
#  'Klebsilla Pneumonia' 'Whooping cough' 'Bronchiseptica' 'Pasteurellosis'
#  'Psuedomonas' 'Coccidiodomycosis' 'Pneumocystis' 'Blastomyces'
#  'Strongyloidiasis' 'Nasal Annelids' 'Angel Wings' 'Aviparvovirus'
#  'Avian Adenovirus' 'Avian Bornavirus' 'Avian Botulis' 'Avian influenza '
#  'Avian Kerathin Disorder' 'Malaria' 'Avian Metapneumovirus'
#  'Avian Sarcoma leukness' 'Avian Vacuolar Myelinopathy' 'Avipoxvirus'
#  'Bumble foot' 'CanaryPox' 'Candidiasis' 'Diphtherictic' 'Canaries'
#  'Easter Equine Encephalities' 'Egg Binding' 'Fatty Liver'
#  'Feather Plucking' 'Gallid Alphaherpervirus' 'Histoplasmosis '
#  'Mycoplasma Synoviac' "Pacheco's" 'Pigeon Pox' 'Polyuria'
#  'Proventricular Dilatation' 'Psittacine Beak' 'Psittacosis' 'Puffiness'
#  'Scaly Foot' 'Respiratory disease' 'Sporotrichosis' 'Tremovirus'
#  'Abomasal Bloat' 'Abomasal empyting defect' 'Abortion'
#  'Cache Valley Virus' 'Campylobacteriosis+' 'Rift Valley Fever' 'Acidosis'
#  'Lactosis Acidosis' 'Ruminal Acidosis' 'Arthritis'
#  'Bacterial Meningritis ' 'Bent Leg' 'Bloat' 'Free Gas Bloat' 'Bluetongue'
#  'Border Disease' 'Hair_Shaker Disease' 'Caseous Lymphadenitis' 'Boils'
#  'Abscesses' 'Cheesy Gland' 'Clostridial Disease' 'Enterotoxemia type c'
#  'Hemorrhagic enteritis' 'Pulpy Kidney ' 'Lamp Dysentery' 'Black Disease'
#  'Black Leg' 'Malignant Edema' 'Cobalt Defiency' 'Copper Defiency'
#  'Copper Toxicity' 'Dystocia' 'Coli Scours' 'Entropion' 'Epididymitis'
#  'External Parasites' 'Fly Strike' 'Sheep Keds' 'Lice' 'Nasal Bots'
#  'Facial Eczema' 'Fescue Toxicosis' 'Footrot' 'Foot Scald' 'Goiter'
#  'Grass tetany' 'Hypothermia' 'Stomach Worms' 'Nematodirus spp'
#  'Liver flukes' 'Meningeal worm' 'Joint Or Navel ill' 'Laminitis'
#  'Ovine Progressive Pneumonia' 'Pizzle Rot' 'Polioencephalomalacia'
#  'Pregnancy Toxemia' 'Rectal Prolapse' 'Ryregrass Staggers' 'Scrapie'
#  'Scrotal hernia' 'Septic Pedal Arthritis' 'Soremouth' 'Spider Syndrome'
#  'Urinary calculi' 'White muscle disease' 'Aborted fetuses' 'Anemia'
#  'Bottle jaw' 'Club Lamb Fungus' 'Deformed lambs' 'Deworming'
#  'Deviated Spine' 'Eye problem' 'Foot Abscess' 'Fungal infection'
#  'Hypocalcemia' 'Infected Ear' 'Injured Eye' 'Intraperitioneal infection'
#  'Necropsy' 'Milk Goiter' 'Sheath' 'Prolase starting' 'Thin ewe'
#  'White Eye' 'Wool loss' 'bronchitis ' 'Epistaxis' 'Choke' 'Impaction'
#  'Gastritis' 'respratory infections' 'potomac horse fever' 'ehv'
#  'equine influenza' 'strangles' 'tetanus' 'duck cholera' 'colic'
#  'gastrointestinal disorders' 'anthrax' 'haemorrhagic septicaemia'
#  'tuberculosis' 'CWD' 'feLV' 'black quarter' 'blue tongue']

# %%
jumlah_penyakit = data['Disease'].value_counts()

print("\nJumlah kemunculan setiap jenis penyakit:")
print(jumlah_penyakit)
# Out:
# Jumlah kemunculan setiap jenis penyakit:
# Disease
# CWD                20
# Rabies             18
# anthrax            10
# Bloat              10
# Brucellosis         9
#                    ..
# Glardiasis          2
# Bladder Cancer      2
# Protothecosis       2
# Bone caner          2
# Aborted fetuses     2
# Name: count, Length: 335, dtype: int64

# %% [markdown]
# Check there is null value

# %%
data.isnull().any
# Out:
# <bound method DataFrame.any of      AnimalName  symptoms1  symptoms2  symptoms3  symptoms4  symptoms5  \
# 0         False      False      False      False      False      False
# 1         False      False      False      False      False      False
# 2         False      False      False      False      False      False
# 3         False      False      False      False      False      False
# 4         False      False      False      False      False      False
# ..          ...        ...        ...        ...        ...        ...
# 866       False      False      False      False      False      False
# 867       False      False      False      False      False      False
# 868       False      False      False      False      False      False
# 869       False      False      False      False      False      False
# 870       False      False      False      False      False      False
#
#      Dangerous  Disease
# 0        False    False
# 1        False    False
# 2        False    False
# 3        False    False
# 4        False    False
# ..         ...      ...
# 866      False    False
# 867      False    False
# 868      False    False
# 869      False    False
# 870      False    False
#
# [871 rows x 8 columns]>

# %% [markdown]
# Split x and y values

# %%
x=data.drop(['Dangerous','Disease'],axis=1)

# %%
y=data.Disease

# %%
x.shape
# Out:
# (871, 6)

# %%
y.shape
# Out:
# (871,)

# %% [markdown]
# Split x,y into train test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=1)

# %%
len(x_train),len(y_train)
# Out:
# (783, 783)

# %%
len(x_test),len(y_test)
# Out:
# (88, 88)

# %% [markdown]
# Applying All columns Onehotencoder

# %%
onehot=OneHotEncoder()
onehot.fit(x[['AnimalName','symptoms1','symptoms2','symptoms3','symptoms4','symptoms5']])
# Out:
# OneHotEncoder()

# %%
a=make_column_transformer((OneHotEncoder(categories=onehot.categories_,handle_unknown = 'ignore'),['AnimalName','symptoms1','symptoms2','symptoms3','symptoms4','symptoms5']),remainder='passthrough')

# %% [markdown]
# Model Creation

# %%
model=RandomForestClassifier()

# %% [markdown]
# Pipe Using

# %%
pipe=make_pipeline(a,model)
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Birds', 'Black-tailed deer', 'Buffaloes', 'Cattle', 'Chicken',
#        'Deer', 'Dog', 'Dogs', 'Donkey', 'Duck', 'Elephant', 'Elk', 'Fowl',
#        'Fox', 'Fox ', 'Goat', 'Goats', 'Hamster', 'Horse', 'Hyaenas',
#        'Lion', 'Monkey', 'Moos', 'Mule deer',...
#        'loss of\xa0wariness', 'recumbency', 'restless movement',
#        'slow growth', 'sudden death', 'swollen abdomen', 'trembling',
#        'twisted neck', 'urination problem', 'weakness',
#        '\xa0increased passing gas', '\xa0pain and bloating'], dtype=object)],
#                                                                 handle_unknown='ignore'),
#                                                   ['AnimalName', 'symptoms1',
#                                                    'symptoms2', 'symptoms3',
#                                                    'symptoms4',
#                                                    'symptoms5'])])),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Birds', 'Black-tailed deer', 'Buffaloes', 'Cattle', 'Chicken',
#        'Deer', 'Dog', 'Dogs', 'Donkey', 'Duck', 'Elephant', 'Elk', 'Fowl',
#        'Fox', 'Fox ', 'Goat', 'Goats', 'Hamster', 'Horse', 'Hyaenas',
#        'Lion', 'Monkey', 'Moos', 'Mule deer',...
#        'loss of\xa0wariness', 'recumbency', 'restless movement',
#        'slow growth', 'sudden death', 'swollen abdomen', 'trembling',
#        'twisted neck', 'urination problem', 'weakness',
#        '\xa0increased passing gas', '\xa0pain and bloating'], dtype=object)],
#                                                                 handle_unknown='ignore'),
#                                                   ['AnimalName', 'symptoms1',
#                                                    'symptoms2', 'symptoms3',
#                                                    'symptoms4',
#                                                    'symptoms5'])])),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
pipe.predict(x_test)
# Out:
# array(['Cobalt Defiency', 'Black Leg', 'campylobacterosis',
#        'Salmonellosis', 'Canine Influenza', 'Feline herpesvirus',
#        'myxomatosis', 'cerebellar hypoplasia', 'Rift Valley Fever', 'CWD',
#        'Ring worm', 'Anemia', 'Canine Influenza', 'Hypocalcemia',
#        'Histoplasmosis', 'Feather Plucking', 'Polioencephalomalacia',
#        'Clostridial Disease', 'Deformed lambs', 'giardiasis',
#        'verminosis', 'Rift Valley Fever', 'Scrotal hernia',
#        'Tuberculosis', 'Hypothermia', 'Chronic Wasting', 'Lyme',
#        'Canine Influenza', 'Haemonchosis', 'Fungal infection',
#        'Black Leg', 'Bloat', 'Whooping cough', 'Soremouth', 'Bone caner',
#        'Epistaxis', 'Contagious Bovin', 'anthrax', 'Stomach Worms',
#        'Coccoidiosis', 'Infectious canine hepatitis', 'Gastritis', 'CWD',
#        'Hypocalcemia', 'Mycoplasma Synoviac',
#        'gastrointestinal disorders', 'Hemangiosarcoma',
#        'Bovine tuberculosis', 'Fatty Liver', 'Diphtherictic', 'Zoonosis',
#        'Blastomyces', 'White Eye', 'Toxoplasma gondii', 'Acidosis',
#        'Kennel cough', 'Injured Eye', 'anthrax', 'Encephalitis',
#        'Rhinitis', 'Avian Bornavirus', 'Toxoplasmosis', 'Epistaxis',
#        'Bloat', 'Copper Defiency', "Marek's", 'White muscle',
#        'leptospirosis', 'Rocky mountain spotted fever', 'Bloat',
#        'HeartWorm', 'haemorrhagic septicaemia', 'Histoplasmosis ',
#        'Coccidiosis', 'Lice', 'Upper respiratory infection', 'anthrax',
#        'tuberculosis', 'Influenza A and B', 'CWD', 'Anthrax',
#        'Trachiobronchial', 'Tick', 'Haemorrhagic Septicemia', 'Ear mites',
#        'tetanus', 'Ticks', 'Histoplasmosis'], dtype=object)

# %% [markdown]
# Check Accuracy

# %%
pipe.score(x_test,y_test)
# Out:
# 0.8068181818181818

# %%
pipe.score(x_train,y_train)
# Out:
# 0.9833971902937421

# %%
import pickle

# %% [markdown]
# Pickle Creation

# %%
pickle.dump(pipe,open('Random1.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Snake','Fever','Difficulty breathing','Poor Appetite','Eye and Skin change','Unable to exercise']],columns=['AnimalName','symptoms1','symptoms2','symptoms3','symptoms4','symptoms5']))
# Out:
# array(['Histoplasmosis'], dtype=object)
